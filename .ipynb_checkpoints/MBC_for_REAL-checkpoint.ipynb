# %%
from collections import OrderedDict
import swmmAPImini as sm
import mbc

# %% [markdown]
# SWMM Input File

# %%
swmmINP = 'NoWestside_withISDs_RainEvents.inp'
simNotes = ['No Control -- Full GDRSS']

# %%
# With or without control?
control = True

# %% [markdown]
# Save Your Shit

# %%
pickleOut = 'orifice_qaqc_56.p'
metaCSV = 'CC_FV_FREUD_meta.csv'

# %% [markdown]
# Read Control Points from CSV files
# CSV files are the files that should be changed

# %%
cF = 'input_files/ControlPoints_Init_CC_FV_FREUD.csv'
uF = 'input_files/Upstream_Init_CC_FV_FREUD.csv'
dF = 'input_files/Downstream_Init_CC_FV_FREUD.csv'
pF = 'input_files/PerformancePoints_Init.csv' # Elements of interest in SWMM to analyze performance

controlDict = sm.return_inputs(cF,'control')
upstreamDict = sm.return_inputs(uF,'upstream')
downstreamDict = sm.return_inputs(dF,'downstream')
performanceDict = sm.return_inputs(pF,'performance')
dsKeys = list(downstreamDict.keys())

# %%
# Change upstream parameters in you'd like.
# for i in upstreamDict:
#     upstreamDict[i]['beta'] = 50.0
#     upstreamDict[i]['uparam'] = 50.0
    
upstreamDict['5010']['max_depth'] = 24.0
upstreamDict['5010']['beta'] = 1.0
upstreamDict['5010']['uparam'] = 1.0

# upstreamDict['17311']['beta'] = 5.0
# upstreamDict['17311']['uparam'] = 5.0
upstreamDict['2912']['beta'] = 0.10
upstreamDict['2912']['uparam'] = 0.10

upstreamDict['5220']['beta'] = 1.0
upstreamDict['5220']['uparam'] = 1.0

downstreamDict['2909']['set_point'] = 0.5
downstreamDict['2909']['epsilson'] = 10.0
downstreamDict['2909']['gamma'] = 10.0
downstreamDict['2909']['max_depth'] = 22.0

# %%
upstreamDict.keys()
# Out:
# odict_keys(['2912', '5220', '5010'])

# %% [markdown]
# Process swmm elements into a dictionary. Change txt element files within swmmAPImini.py

# %%
conduits,nodes,storages,subcatchments,outfalls,orifices,pumps = sm.make_element_dictionaries()

# %% [markdown]
# Get depth and flow information from swmm element dictionaries

# %%
sm.get_depth(upstreamDict,conduits,storages)
sm.get_depth(downstreamDict,conduits,storages)
sm.get_q_full_and_other(downstreamDict,conduits,storages)
sm.orifice_xsect_grab(controlDict,orifices)
sm.pump_curve_grab(controlDict,pumps)

timestep = sm.get_timestep(swmmINP)

sm.performance_elements(performanceDict,conduits,nodes,storages,subcatchments,outfalls,orifices,pumps)
dsKeys = list(downstreamDict.keys())

# %% [markdown]
# Variable Management

# %%
try:
    del conduits
    del nodes
    del storages
    del subcatchments
    del outfalls
except:
    pass

# %%
# downstreamDict[dsKeys[0]]['max_flow'] = 1.0
print(timestep)
# Out:
# 30.0

# %%
# %%time
price, PDemand = mbc.run_control_sim(control,controlDict,upstreamDict,downstreamDict,dsKeys,swmmINP,performanceDict,timestep)
# Out:
# running simulation...
# done ...
# Wall time: 21.9 s

# %% [markdown]
# # Save That Shit

# %%
saveDict = {
    'controlDict':controlDict,
    'upstreamDict':upstreamDict,
    'downstreamDict':downstreamDict,
    'metaCSV':metaCSV,
    'pickleOut':pickleOut,
    'notes':simNotes,
    'file':swmmINP,
    'control':str(control),
    'performanceDict':performanceDict
}

try:
    saveDict['price'] = price
    saveDict['PDemand'] = PDemand
except:
    pass

mbc.save_that_shit(saveDict)

# %% [markdown]
# # Visualize That Shit

# %%
from collections import OrderedDict
import swmmAPImini as sm
import mbc

import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
# %matplotlib inline
f_nocontrol = 'orifice_qaqc_55.p'
f_control = 'orifice_qaqc_43.p'
# f_nocontrol = pickleOut
# f_control = pickleOut
# figname = 'OrificeQaQc_half_inch' + f_nocontrol[:-2] + '.png'
figname = 'noControl_and_pickle43.png'

mbc.viz_shit(f_nocontrol,f_control,figname)

with open(f_control,'rb') as f:
    data = pickle.load(f)
    
    upstreamDict = data['upstreamDict']
    downstreamDict = data['downstreamDict']
    controlDict = data['controlDict']
    performanceDict = data['performanceDict']

fig = plt.subplots(figsize=(15,12))
for i in upstreamDict:
    plt.plot(upstreamDict[i]['ts'])
    
plt.plot(downstreamDict['2909']['ts_depth'],color='k')  

for i in controlDict:
    plt.scatter(np.array([j for j in range(0,len(controlDict[i]['actionTS']))]),controlDict[i]['actionTS'],s=3)
    

plt.legend([upstreamDict[i]['location'] for i in upstreamDict]+['CC RTB']+[controlDict[i]['location'] for i in controlDict])

plt.title('Target Settings and Depth For Control Assets')
plt.ylabel('Normalized Depth & Actions')
plt.xlabel('Simulation Time')
plt.show()
plt.close()


fig = plt.subplots(figsize=(15,12))
x = np.array([i for i in range(0,len(performanceDict['PUMP44@5220-5219']['ts_flow']))])
plt.scatter(x,performanceDict['PUMP44@5220-5219']['ts_flow'],s=3)
plt.scatter(x,performanceDict['PUMP34@5010-5009']['ts_flow'],s=3)
plt.scatter(x,performanceDict['ORIFICE33@17312-17313']['ts_flow'],s=3)
plt.scatter(x,performanceDict['2908']['ts_flow'],s=3) # CSO Outfall
plt.scatter(x,performanceDict['ORIFICE22@2909-2999']['ts_flow'],s=3) # CC RTB Dewatering
plt.title('Flow from Control Locations')
plt.legend(['PUMP 44, FREUD', 'PUMP 34, CC','CC FOREBAY', 'CSO Outfall', 'CC '])
plt.ylabel('Flow [cfs]')
plt.xlabel('Simulation Time')
plt.show()
plt.close()

# %%
mbc.viz_shit(f_nocontrol,f_control,figname)

# %%
# with open(f_control,'rb') as f:
#     data = pickle.load(f)
    
#     upstreamDict = data['upstreamDict']
#     downstreamDict = data['downstreamDict']
#     controlDict = data['controlDict']
#     performanceDict = data['performanceDict']

# performanceDict.keys()
# Out:
# odict_keys(['1002', '200', '100', '1686', '2908', 'ORIFICE22@2909-2999', '17313', '50091', '50092'])

# %%
# for i in upstreamDict:
#     plt.plot(upstreamDict[i]['ts'])
    
# plt.plot(downstreamDict['2909']['ts_depth'],color='k')  

# for i in controlDict:
#     plt.scatter(np.array([j for j in range(0,len(controlDict[i]['actionTS']))]),controlDict[i]['actionTS'],s=3)
    

# plt.legend([upstreamDict[i]['location'] for i in upstreamDict]+['CC RTB']+[controlDict[i]['location'] for i in controlDict],loc=4)

# plt.title('Target Settings and Depth For Control Assets')
# plt.ylabel('Normalized Depth & Actions')
# plt.xlabel('Simulation Time')
# plt.show()
# plt.close()

# x = np.array([i for i in range(0,len(performanceDict['PUMP44@5220-5219']['ts_flow']))])
# plt.scatter(x,performanceDict['PUMP44@5220-5219']['ts_flow'],s=3)
# plt.scatter(x,performanceDict['PUMP34@5010-5009']['ts_flow'],s=3)
# plt.scatter(x,performanceDict['ORIFICE33@17312-17313']['ts_flow'],s=3)
# plt.scatter(x,performanceDict['2908']['ts_flow'],s=3) # CSO Outfall
# plt.scatter(x,performanceDict['ORIFICE22@2909-2999']['ts_flow'],s=3) # CC RTB Dewatering
# plt.title('Flow from Control Locations')
# plt.legend(['PUMP 44, FREUD', 'PUMP 34, CC','CC FOREBAY', 'CSO Outfall', 'CC '])
# plt.ylabel('Flow [cfs]')
# plt.xlabel('Simulation Time')
# plt.show()
# plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-e35d05b2b162> in <module>()
#      16 plt.close()
#      17
# ---> 18 x = np.array([i for i in range(0,len(performanceDict['PUMP44@5220-5219']['ts_flow']))])
#      19 plt.scatter(x,performanceDict['PUMP44@5220-5219']['ts_flow'],s=3)
#      20 plt.scatter(x,performanceDict['PUMP34@5010-5009']['ts_flow'],s=3)
#
# KeyError: 'PUMP44@5220-5219'

# %%
# plt.plot(performanceDict['ORIFICE22@2909-2999']['ts_flow'])
# plt.plot(performanceDict['2908']['ts_flow'])
# plt.plot(performanceDict['50092']['ts_flow'])

# plt.legend(['CSO Outfall', 'CC PS overflow'])
# plt.show()
# plt.close()

# %%
# plt.scatter(x,controlDict['ORIFICE33@17312-17313']['actionTS'],s=3)
